# %%
# prepare tensor calculations for binder

# %% [raw]
# 1. run test with anaconda - what is missing?
# 2. replace CifFile with cctbx for CIF read?
#
# https://cctbx.github.io/iotbx/iotbx.cif.html
#
# imports:
#
# import sys, pprint
# from copy import deepcopy
# from numpy.linalg import inv
# from numpy.random import rand
# from scipy.special import factorial
# import numpy as np
# from numpy.linalg import det, norm
# import matplotlib.pyplot as plt
#
# import cctbx.sgtbx as sg
#
# import CifFile

# %%
run 'TensorScatteringClass'
# Out:
# === Trying to load crystal data from CIF file...
#
# Crystal properties
#
#                     CIF file:  ZnO Kisi et al icsd_67454.cif
#                      Lattice:  3.250 3.250 5.207 90.00 90.00 120.00
#                    All sites:  Zn1, O1
#                Site selected:  Zn1
#                  Site vector:  0.333 0.667 0.000
#        No. of spacegroup ops:  12
#       No. of sym ops at site:  6
#  No. of equiv. sites in cell:  2
#    No. of pg ops for crystal:  12
#
# Tensor properties
#
#              Required parity:  Odd
#           Required time sym.:  Even
#                          hkl:  [1.0, 1.0, 1.0]
#                 Site allowed:  No
#    Structure factor for site:  0.00+0.00i
#           Spacegroup allowed:  No
#               Tensor allowed:  Yes
#                       Parity:  Either
#                         Time:  Either
#                           PT:  Either
#               Glide or screw:  True
# Tensor components
#
# ...

# %% [raw]
# import TensorScatteringClass as ten
# import numpy as np
# cifpath = '/home/spc93/spc_cifs/'
# ciffile=cifpath+'FeLiAs_P4nmm_icsd_42331_cifbib.cif'
# en = FeK = 7.11
# t=ten.TensorScatteringClass(CIFfile=ciffile, Site='Fe1');
#
# #non-resonant magnetic scattering and resonant scattering
#
#
# t.PlotIntensityInPolarizationChannels('E1E2', lam=12.4/en, hkl = np.array([0,1,0]), hkln = np.array([1,0,0]) , K=3, Time=1, Parity=-1, sigmapi='sigma'); print('=== tth: %.2f deg' % (t.theta * 2 *180./np.pi))
# t.print_tensors()

# %%
import cctbx

# %%
cctbx
